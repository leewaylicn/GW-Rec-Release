# %%
import sagemaker
import json

train_instance_type = 'ml.p3.2xlarge'

hyperparameters = {'learning_rate': 0.0001,  
                   'servable_model_dir': '/opt/ml/model', 
                   'loss_weight': 1.0,
                   'use_context': True, 
                   'max_click_history': 30,  
                   'num_epochs': 1,
                   'max_title_length': 16,  
                   'entity_dim': 128,  
                   'word_dim': 300,  
                   'batch_size': 128,  
                   'perform_shuffle': 1, 
                   'checkpointPath': '/opt/ml/checkpoints'}

byoc_est = sagemaker.estimator.Estimator('662566784674.dkr.ecr.ap-northeast-1.amazonaws.com/gw-dkn:20201114025113',
                                    role=sagemaker.get_execution_role(),
                                    train_instance_count=1, 
                                    train_instance_type=train_instance_type,
                                    base_job_name='dkn-byoc',
                                    hyperparameters=hyperparameters)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
train_s3 = "s3://leigh-gw/train.csv/"
test_s3 = "s3://leigh-gw/test.csv/"
inputs = {'train': train_s3 , 'eval': test_s3}

byoc_est.fit(inputs)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-11-14 03:09:54 Starting - Starting the training job...
# 2020-11-14 03:09:56 Starting - Launching requested ML instances.........
# 2020-11-14 03:11:32 Starting - Preparing the instances for training.........
# 2020-11-14 03:13:05 Downloading - Downloading input data...
# 2020-11-14 03:13:28 Training - Downloading the training image.........
# 2020-11-14 03:15:24 Training - Training image download completed. Training in progress..WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2020-11-14 03:15:27,723 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-11-14 03:15:27,725 sagemaker-training-toolkit INFO     Failed to parse hyperparameter checkpointPath value /opt/ml/checkpoints to Json.
# Returning the value itself
# 2020-11-14 03:15:27,725 sagemaker-training-toolkit INFO     Failed to parse hyperparameter servable_model_dir value /opt/ml/model to Json.
# Returning the value itself
# 2020-11-14 03:15:27,725 sagemaker-training-toolkit INFO     Failed to parse hyperparameter use_context value True to Json.
# Returning the value itself
# 2020-11-14 03:15:27,833 sagemaker-training-toolkit INFO     Failed to parse hyperparameter checkpointPath value /opt/ml/checkpoints to Json.
# Returning the value itself
# 2020-11-14 03:15:27,833 sagemaker-training-toolkit INFO     Failed to parse hyperparameter servable_model_dir value /opt/ml/model to Json.
# Returning the value itself
# 2020-11-14 03:15:27,833 sagemaker-training-toolkit INFO     Failed to parse hyperparameter use_context value True to Json.
# Returning the value itself
# 2020-11-14 03:15:27,858 sagemaker-training-toolkit INFO     Failed to parse hyperparameter checkpointPath value /opt/ml/checkpoints to Json.
# Returning the value itself
# 2020-11-14 03:15:27,858 sagemaker-training-toolkit INFO     Failed to parse hyperparameter servable_model_dir value /opt/ml/model to Json.
# Returning the value itself
# 2020-11-14 03:15:27,858 sagemaker-training-toolkit INFO     Failed to parse hyperparameter use_context value True to Json.
# Returning the value itself
# 2020-11-14 03:15:27,881 sagemaker-training-toolkit INFO     Failed to parse hyperparameter checkpointPath value /opt/ml/checkpoints to Json.
# Returning the value itself
# 2020-11-14 03:15:27,882 sagemaker-training-toolkit INFO     Failed to parse hyperparameter servable_model_dir value /opt/ml/model to Json.
# Returning the value itself
# 2020-11-14 03:15:27,882 sagemaker-training-toolkit INFO     Failed to parse hyperparameter use_context value True to Json.
# Returning the value itself
# 2020-11-14 03:15:27,893 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "entity_dim": 128,
#         "max_title_length": 16,
#         "checkpointPath": "/opt/ml/checkpoints",
#         "word_dim": 300,
#         "max_click_history": 30,
#         "servable_model_dir": "/opt/ml/model",
#         "learning_rate": 0.0001,
#         "loss_weight": 1.0,
#         "use_context": "True",
#         "num_epochs": 1,
#         "perform_shuffle": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "dkn-byoc-2020-11-14-03-09-54-089",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "embed_dkn",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "embed_dkn.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"checkpointPath":"/opt/ml/checkpoints","entity_dim":128,"learning_rate":0.0001,"loss_weight":1.0,"max_click_history":30,"max_title_length":16,"num_epochs":1,"perform_shuffle":1,"servable_model_dir":"/opt/ml/model","use_context":"True","word_dim":300}
# SM_USER_ENTRY_POINT=embed_dkn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=embed_dkn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":128,"checkpointPath":"/opt/ml/checkpoints","entity_dim":128,"learning_rate":0.0001,"loss_weight":1.0,"max_click_history":30,"max_title_length":16,"num_epochs":1,"perform_shuffle":1,"servable_model_dir":"/opt/ml/model","use_context":"True","word_dim":300},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"dkn-byoc-2020-11-14-03-09-54-089","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"embed_dkn","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"embed_dkn.py"}
# SM_USER_ARGS=["--batch_size","128","--checkpointPath","/opt/ml/checkpoints","--entity_dim","128","--learning_rate","0.0001","--loss_weight","1.0","--max_click_history","30","--max_title_length","16","--num_epochs","1","--perform_shuffle","1","--servable_model_dir","/opt/ml/model","--use_context","True","--word_dim","300"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=128
# SM_HP_ENTITY_DIM=128
# SM_HP_MAX_TITLE_LENGTH=16
# SM_HP_CHECKPOINTPATH=/opt/ml/checkpoints
# SM_HP_WORD_DIM=300
# SM_HP_MAX_CLICK_HISTORY=30
# SM_HP_SERVABLE_MODEL_DIR=/opt/ml/model
# SM_HP_LEARNING_RATE=0.0001
# SM_HP_LOSS_WEIGHT=1.0
# SM_HP_USE_CONTEXT=True
# SM_HP_NUM_EPOCHS=1
# SM_HP_PERFORM_SHUFFLE=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 embed_dkn.py --batch_size 128 --checkpointPath /opt/ml/checkpoints --entity_dim 128 --learning_rate 0.0001 --loss_weight 1.0 --max_click_history 30 --max_title_length 16 --num_epochs 1 --perform_shuffle 1 --servable_model_dir /opt/ml/model --use_context True --word_dim 300
#
#
# check input params:
# ['embed_dkn.py', '--batch_size', '128', '--checkpointPath', '/opt/ml/checkpoints', '--entity_dim', '128', '--learning_rate', '0.0001', '--loss_weight', '1.0', '--max_click_history', '30', '--max_title_length', '16', '--num_epochs', '1', '--perform_shuffle', '1', '--servable_model_dir', '/opt/ml/model', '--use_context', 'True', '--word_dim', '300']
# task_type  train
# model_dir
# checkpoint_dir  /opt/ml/checkpoints
# data_dir
# dt_dir  20201113
# num_epochs  1
# batch_size  128
# loss_type  log_loss
# optimizer  Adam
# learning_rate  0.0001
# embed_l2  1e-05
# layer_l2  0.001
# shuffle  1
# train dir is /opt/ml/input/data/train
# eval dir is /opt/ml/input/data/eval
# tr_files: ['/opt/ml/input/data/train/part-00007-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00002-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/train_test.csv', '/opt/ml/input/data/train/part-00012-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00014-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00008-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00000-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00023-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00010-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00017-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00022-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00021-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00018-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00024-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00011-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00015-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00020-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00019-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00001-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00006-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00016-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00005-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00013-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00009-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00004-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00025-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00003-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv']
# va_files: ['/opt/ml/input/data/eval/part-00013-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00021-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00004-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00025-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00018-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00022-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00007-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00015-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00002-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00024-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00003-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00006-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00010-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00000-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00017-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00016-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00011-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00019-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00005-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00020-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00014-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00001-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00023-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/test_test.csv', '/opt/ml/input/data/eval/part-00008-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00009-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00012-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv']
# te_files: None
# sagemaker mode building ...
# finish train, start eval
# sagemaker mode epoch 1 test_auc is 0.6239
# finish saving model!
# 2020-11-14 03:21:09,824 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2020-11-14 03:21:24 Uploading - Uploading generated training model
# 2020-11-14 03:21:24 Completed - Training job completed
# Training seconds: 499
# Billable seconds: 499

# %%
# test sagemaker mode
import sagemaker
from sagemaker.tensorflow import TensorFlow

# train_instance_type = 'local'
train_instance_type = 'ml.p3.2xlarge'

hyperparameters = {'learning_rate': 0.0001,  
                   'servable_model_dir': '/opt/ml/model', 
                   'loss_weight': 1.0,
                   'use_context': True, 
                   'max_click_history': 30,  
                   'num_epochs': 1,
                   'max_title_length': 16,  
                   'entity_dim': 128,  
                   'word_dim': 300,  
                   'batch_size': 128,  
                   'perform_shuffle': 1, 
                   'checkpointPath': '/opt/ml/checkpoints'}

local_estimator = TensorFlow(
                       entry_point='embed_dkn.py',
                       model_dir = '/opt/ml/model',
                       source_dir = 'recsys_tools/recsys_kg/',
                       train_instance_type=train_instance_type,
                       train_instance_count=1,
                       hyperparameters=hyperparameters,
                       role=sagemaker.get_execution_role(),
                       base_job_name='tf-scriptmode-embed-dkn',
                       framework_version='1.15',
                    #    distributions=distributions,
                       py_version='py3')

# %%
train_s3 = "s3://leigh-gw/train.csv/"
test_s3 = "s3://leigh-gw/test.csv/"
inputs = {'train': train_s3 , 'eval': test_s3}
local_estimator.fit(inputs)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-11-14 02:25:47 Starting - Starting the training job...
# 2020-11-14 02:25:49 Starting - Launching requested ML instances.........
# 2020-11-14 02:27:22 Starting - Preparing the instances for training......
# 2020-11-14 02:28:30 Downloading - Downloading input data...
# 2020-11-14 02:29:05 Training - Downloading the training image...
# 2020-11-14 02:29:47 Training - Training image download completed. Training in progress..WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2020-11-14 02:29:51,298 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-11-14 02:29:51,800 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "word_dim": 300,
#         "loss_weight": 1.0,
#         "perform_shuffle": 1,
#         "entity_dim": 128,
#         "max_title_length": 16,
#         "checkpointPath": "/opt/ml/checkpoints",
#         "max_click_history": 30,
#         "servable_model_dir": "/opt/ml/model",
#         "model_dir": "/opt/ml/model",
#         "learning_rate": 0.0001,
#         "use_context": true,
#         "num_epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tf-scriptmode-embed-dkn-2020-11-14-02-25-47-053",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-662566784674/tf-scriptmode-embed-dkn-2020-11-14-02-25-47-053/source/sourcedir.tar.gz",
#     "module_name": "embed_dkn",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "embed_dkn.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"checkpointPath":"/opt/ml/checkpoints","entity_dim":128,"learning_rate":0.0001,"loss_weight":1.0,"max_click_history":30,"max_title_length":16,"model_dir":"/opt/ml/model","num_epochs":1,"perform_shuffle":1,"servable_model_dir":"/opt/ml/model","use_context":true,"word_dim":300}
# SM_USER_ENTRY_POINT=embed_dkn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=embed_dkn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-662566784674/tf-scriptmode-embed-dkn-2020-11-14-02-25-47-053/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":128,"checkpointPath":"/opt/ml/checkpoints","entity_dim":128,"learning_rate":0.0001,"loss_weight":1.0,"max_click_history":30,"max_title_length":16,"model_dir":"/opt/ml/model","num_epochs":1,"perform_shuffle":1,"servable_model_dir":"/opt/ml/model","use_context":true,"word_dim":300},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-scriptmode-embed-dkn-2020-11-14-02-25-47-053","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-662566784674/tf-scriptmode-embed-dkn-2020-11-14-02-25-47-053/source/sourcedir.tar.gz","module_name":"embed_dkn","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"embed_dkn.py"}
# SM_USER_ARGS=["--batch_size","128","--checkpointPath","/opt/ml/checkpoints","--entity_dim","128","--learning_rate","0.0001","--loss_weight","1.0","--max_click_history","30","--max_title_length","16","--model_dir","/opt/ml/model","--num_epochs","1","--perform_shuffle","1","--servable_model_dir","/opt/ml/model","--use_context","True","--word_dim","300"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=128
# SM_HP_WORD_DIM=300
# SM_HP_LOSS_WEIGHT=1.0
# SM_HP_PERFORM_SHUFFLE=1
# SM_HP_ENTITY_DIM=128
# SM_HP_MAX_TITLE_LENGTH=16
# SM_HP_CHECKPOINTPATH=/opt/ml/checkpoints
# SM_HP_MAX_CLICK_HISTORY=30
# SM_HP_SERVABLE_MODEL_DIR=/opt/ml/model
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_LEARNING_RATE=0.0001
# SM_HP_USE_CONTEXT=true
# SM_HP_NUM_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 embed_dkn.py --batch_size 128 --checkpointPath /opt/ml/checkpoints --entity_dim 128 --learning_rate 0.0001 --loss_weight 1.0 --max_click_history 30 --max_title_length 16 --model_dir /opt/ml/model --num_epochs 1 --perform_shuffle 1 --servable_model_dir /opt/ml/model --use_context True --word_dim 300
#
#
# check input params:
# ['embed_dkn.py', '--batch_size', '128', '--checkpointPath', '/opt/ml/checkpoints', '--entity_dim', '128', '--learning_rate', '0.0001', '--loss_weight', '1.0', '--max_click_history', '30', '--max_title_length', '16', '--model_dir', '/opt/ml/model', '--num_epochs', '1', '--perform_shuffle', '1', '--servable_model_dir', '/opt/ml/model', '--use_context', 'True', '--word_dim', '300']
# task_type  train
# model_dir  /opt/ml/model
# checkpoint_dir  /opt/ml/checkpoints
# data_dir
# dt_dir  20201113
# num_epochs  1
# batch_size  128
# loss_type  log_loss
# optimizer  Adam
# learning_rate  0.0001
# embed_l2  1e-05
# layer_l2  0.001
# shuffle  1
# train dir is /opt/ml/input/data/train
# eval dir is /opt/ml/input/data/eval
# tr_files: ['/opt/ml/input/data/train/part-00025-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00000-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00010-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00017-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00009-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00006-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00016-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00022-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00014-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00005-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00008-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00021-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00023-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00019-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00007-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00012-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00013-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00002-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00015-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00004-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00011-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00020-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/train_test.csv', '/opt/ml/input/data/train/part-00003-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00018-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00001-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv', '/opt/ml/input/data/train/part-00024-825b9cb0-4804-4920-b43a-d603ba433067-c000.csv']
# va_files: ['/opt/ml/input/data/eval/part-00013-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00005-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00006-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00002-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00022-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00009-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00025-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00014-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00010-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00001-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00021-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00008-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00000-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00015-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00019-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/test_test.csv', '/opt/ml/input/data/eval/part-00012-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00017-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00007-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00003-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00024-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00018-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00004-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00011-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00020-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00023-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv', '/opt/ml/input/data/eval/part-00016-0bfa21fb-25b6-40f9-b86e-06bf9dd7d064-c000.csv']
# te_files: None
# sagemaker mode building ...
# [2020-11-14 02:29:54.234 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-14 02:29:54.234 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-14 02:29:54.235 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2020-11-14 02:29:54.235 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2020-11-14 02:29:57.976 ip-10-0-65-168.ap-northeast-1.compute.internal:33 WARNING collection.py:91] Could not add IndexedSlices(indices=Tensor("train/gradients/concat_1:0", shape=(63488,), dtype=int32), values=Tensor("train/gradients/concat:0", shape=(63488, 300), dtype=float32), dense_shape=Tensor("train/gradients/DKN/attention_net/kcnn/embedding_lookup_3_grad/Cast:0", shape=(2,), dtype=int32)) of type <class 'tensorflow.python.framework.indexed_slices.IndexedSlices'> to collection gradients.Add can only take tf.Operation, tf.Variable, tf.Tensor, tf.MirroredVariable and list or set of any of the above.
# [2020-11-14 02:29:59.539 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO hook.py:398] Monitoring the collections: sm_metrics, losses, metrics
# finish train, start eval
# [2020-11-14 02:34:53.714 ip-10-0-65-168.ap-northeast-1.compute.internal:33 WARNING collection.py:91] Could not add IndexedSlices(indices=Tensor("train/gradients/concat_1:0", shape=(63488,), dtype=int32), values=Tensor("train/gradients/concat:0", shape=(63488, 300), dtype=float32), dense_shape=Tensor("train/gradients/DKN/attention_net/kcnn/embedding_lookup_3_grad/Cast:0", shape=(2,), dtype=int32)) of type <class 'tensorflow.python.framework.indexed_slices.IndexedSlices'> to collection gradients.Add can only take tf.Operation, tf.Variable, tf.Tensor, tf.MirroredVariable and list or set of any of the above.
# [2020-11-14 02:34:54.065 ip-10-0-65-168.ap-northeast-1.compute.internal:33 INFO hook.py:398] Monitoring the collections: sm_metrics, losses, metrics
# sagemaker mode epoch 1 test_auc is 0.6284
# finish saving model!
# 2020-11-14 02:35:21,972 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2020-11-14 02:35:39 Uploading - Uploading generated training model
# 2020-11-14 02:35:39 Completed - Training job completed
# Training seconds: 429
# Billable seconds: 429
